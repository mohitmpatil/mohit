# %%
pwd
# Out:
# 'C:\\Users\\Dell\\CDRC'

# %%
import pandas as pd
df = pd.read_csv('Gaussian Random number 8260 - Sheet1.csv')

# %%
df.head();

# %%
2+3
# Out:
# 5

# %%
import pandas as pd
df = pd.read_csv(r"Gaussian Random number 8260 - Sheet1.csv")
print(df.head())
# Create a DataFrame       

dataFrame = pd.DataFrame(df, index=("R1"), columns=("C1"));

print("Contents of the DataFrame:");

print(dataFrame);

 

# Convert the DataFrame to Series

dictionaryObject = dataFrame.to_dict();

print("DataFrame as a dictionary:");

print(dictionaryObject);
# Out:
#    0.03673972713
# 0       0.501186
# 1       0.118338
# 2       0.452479
# 3       0.464493
# 4       0.997504
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-8a75ded54cce> in <module>
#       4 # Create a DataFrame
#       5
# ----> 6 dataFrame = pd.DataFrame(df, index=("R1"), columns=("C1"));
#       7
#       8 print("Contents of the DataFrame:");
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     522                 return
#     523
# --> 524             mgr = self._init_mgr(
#     525                 data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     526             )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _init_mgr(cls, mgr, axes, dtype, copy)
#     209         for a, axe in axes.items():
#     210             if axe is not None:
# ...

# %%
import pandas as pd
df = pd.read_csv(r"Gaussian Random number 8260 - Sheet2.csv")
print(df.head())
# Out:
#    0.036739727  0.82137833
# 0     0.501186    0.627213
# 1     0.118338    0.767372
# 2     0.452479    0.391894
# 3     0.464493    0.209211
# 4     0.997504    0.067759

# %%
import pandas as pd
df = pd.read_csv(r"Gaussian Random number 8260 - Sheet1.csv")
print(df.head())
# Create a DataFrame       

dataFrame = pd.DataFrame(df);

print("Contents of the DataFrame:");

print(dataFrame);

 

# Convert the DataFrame to Series

dictionaryObject = dataFrame.to_dict();

print("DataFrame as a dictionary:");

print(dictionaryObject);
# Out:
#    0.03673972713
# 0       0.501186
# 1       0.118338
# 2       0.452479
# 3       0.464493
# 4       0.997504
# Contents of the DataFrame:
#       0.03673972713
# 0          0.501186
# 1          0.118338
# 2          0.452479
# 3          0.464493
# 4          0.997504
# ...             ...
# 8254       0.189645
# 8255       0.380077
# 8256       0.637419
# 8257       0.413127
# 8258       0.628951
#
# [8259 rows x 1 columns]
# DataFrame as a dictionary:
# ...
