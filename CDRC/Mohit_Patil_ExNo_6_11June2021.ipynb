# %%
import pandas as pd

df = pd.read_json('final.json')
print(df)
#print(df.to_numpy()) 
data=pd.DataFrame(df)
# Out:
#                               Gaussian Rand No Set 2  \
# 0                                           0.501801
# 1                                           0.501329
# 2                                           0.287134
# 3  {'0': 0.000181843, '1': 0.000297472, '2': 0.00...
#
#                               Gaussian Rand No Set 1
# 0                                           0.504582
# 1                                           0.507249
# 2                                           0.290327
# 3  {'0': 9.54e-05, '1': 0.00022103700000000002, '...

# %%
print(data.head(1))
# Out:
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582

# %%
mean=data.head(1)
med=data.head(2)
std=data.head(3)
Mode2=data.head(4)


print(mean)
print(med)
print(std)
print(Mode1)
# Out:
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582
# 1               0.501329               0.507249
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582
# 1               0.501329               0.507249
# 2               0.287134               0.290327
#                               Gaussian Rand No Set 2  \
# 0                                           0.501801
# 1                                           0.501329
# 2                                           0.287134
# 3  {'0': 0.000181843, '1': 0.000297472, '2': 0.00...
#
#                               Gaussian Rand No Set 1
# 0                                           0.504582
# 1                                           0.507249
# 2                                           0.290327
# ...

# %%
import pandas as pd
import numpy as np
from  matplotlib import pyplot as plt
np=data.to_numpy()
mean=np[0]
med=np[1]
std=np[2]
Mode=np[3]
print("\n-------------------  Mean -----------------\n")
plt.plot(mean)
plt.show()
plt.savefig('MEAN.png')
print("\n-------------------  Median ----------------\n")
plt.plot(med)
plt.show()
plt.savefig('MEDIAN.png')

print("\n-------------- Standard deviation -----------\n")
plt.plot(std)
plt.show()
plt.savefig('STANDARD DEVIATION.png')

#print("\n-------------- Standard deviation -----------\n")
#plt.plot(Mode)
#plt.show()
# Out:
# -------------------  Mean -----------------
# -------------------  Median ----------------
# -------------- Standard deviation -----------

# %%
import numpy as np
import matplotlib.pyplot as plt, mpld3
from matplotlib.widgets import CheckButtons


fig, ax = plt.subplots()
l0, = plt.plot(mean)
l1, = plt.plot(med)
l2, = plt.plot(std)

plt.subplots_adjust(left=0.2)

rax = plt.axes([0.05, 0.4, 0.1, 0.15])
check = CheckButtons(rax, ('Mean', 'Median', 'STD'), (True, True, True))
mpld3.save_html(fig, 'Final_fig_mean_median_standard deviation.html') #save to html here
plt.show()
