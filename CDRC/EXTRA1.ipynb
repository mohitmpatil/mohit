# %%
import pandas as pd

df = pd.read_json('final.json')
print(df)
#print(df.to_numpy())
# Out:
#                               Gaussian Rand No Set 2  \
# 0                                           0.501801
# 1                                           0.501329
# 2                                           0.287134
# 3  {'0': 0.000181843, '1': 0.000297472, '2': 0.00...
#
#                               Gaussian Rand No Set 1
# 0                                           0.504582
# 1                                           0.507249
# 2                                           0.290327
# 3  {'0': 9.54e-05, '1': 0.00022103700000000002, '...

# %%
print(df.to_numpy())
# Out:
# [[0.501800769065132 0.5045821537184]
#  [0.5013292770000001 0.5072492195]
#  [0.28713380461458804 0.29032744196243104]
# ...

# %%
data=pd.DataFrame(df)
mean=data.head(1)
med=data.head(2)
std=data.head(3)
Mode=data.head(4)


print(mean)
print(med)
print(std)
print(Mode)
# Out:
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582
# 1               0.501329               0.507249
#   Gaussian Rand No Set 2 Gaussian Rand No Set 1
# 0               0.501801               0.504582
# 1               0.501329               0.507249
# 2               0.287134               0.290327
#                               Gaussian Rand No Set 2  \
# 0                                           0.501801
# 1                                           0.501329
# 2                                           0.287134
# 3  {'0': 0.000181843, '1': 0.000297472, '2': 0.00...
#
#                               Gaussian Rand No Set 1
# 0                                           0.504582
# 1                                           0.507249
# 2                                           0.290327
# ...

# %%
import pandas as pd
import numpy as np
from  matplotlib import pyplot as plt
np=data.to_numpy()
print(np[2])
p=np[2]
plt.plot(np[2])
plt.show()
print(np[1])

plt.plot(np[1])
plt.show()
print(np[0])

plt.plot(np[0])
plt.show()
# Out:
# [0.28713380461458804 0.29032744196243104]
# [0.5013292770000001 0.5072492195]
# [0.501800769065132 0.5045821537184]

# %%
print(np[3])

plt.plot(np[3])
plt.show()
# Out:
# [{'0': 0.000181843, '1': 0.000297472, '2': 0.000608122, '3': 0.0007123920000000001, '4': 0.000904051, '5': 0.001226283, '6': 0.0012336790000000001, '7': 0.001273238, '8': 0.0013060950000000002, '9': 0.001634435, '10': 0.0016475250000000002, '11': 0.00167776, '12': 0.001784318, '13': 0.00195884, '14': 0.002127654, '15': 0.0025491520000000003, '16': 0.002562899, '17': 0.002653981, '18': 0.002772773, '19': 0.00331774, '20': 0.003459283, '21': 0.0035025430000000003, '22': 0.003676365, '23': 0.0037093860000000003, '24': 0.003811202, '25': 0.004042014, '26': 0.00405072, '27': 0.0045908880000000004, '28': 0.004870015, '29': 0.004888314, '30': 0.005071859000000001, '31': 0.005139431000000001, '32': 0.005187841, '33': 0.0053197290000000005, '34': 0.00538475, '35': 0.005646827, '36': 0.005746112, '37': 0.005760929000000001, '38': 0.005871965000000001, '39': 0.006102167, '40': 0.006143481, '41': 0.006236972, '42': 0.006374963, '43': 0.006483413, '44': 0.0064837820000000004, '45': 0.006501831000
# ...

# %%
print(np[3].toDataFrame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-67fcbe489d0c> in <module>
# ----> 1 print(np[3].toDataFrame)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toDataFrame'

# %%
x= np[3]
print(x)
# Out:
# [{'0': 0.000181843, '1': 0.000297472, '2': 0.000608122, '3': 0.0007123920000000001, '4': 0.000904051, '5': 0.001226283, '6': 0.0012336790000000001, '7': 0.001273238, '8': 0.0013060950000000002, '9': 0.001634435, '10': 0.0016475250000000002, '11': 0.00167776, '12': 0.001784318, '13': 0.00195884, '14': 0.002127654, '15': 0.0025491520000000003, '16': 0.002562899, '17': 0.002653981, '18': 0.002772773, '19': 0.00331774, '20': 0.003459283, '21': 0.0035025430000000003, '22': 0.003676365, '23': 0.0037093860000000003, '24': 0.003811202, '25': 0.004042014, '26': 0.00405072, '27': 0.0045908880000000004, '28': 0.004870015, '29': 0.004888314, '30': 0.005071859000000001, '31': 0.005139431000000001, '32': 0.005187841, '33': 0.0053197290000000005, '34': 0.00538475, '35': 0.005646827, '36': 0.005746112, '37': 0.005760929000000001, '38': 0.005871965000000001, '39': 0.006102167, '40': 0.006143481, '41': 0.006236972, '42': 0.006374963, '43': 0.006483413, '44': 0.0064837820000000004, '45': 0.006501831000
# ...

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(np[3])
# Out:
# numpy.ndarray

# %%
shape(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-55ca915756b0> in <module>
# ----> 1 shape(x)
#
# NameError: name 'shape' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-bf81cd6f90f5> in <module>
# ----> 1 y=x.tostr([2])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'tostr'
